# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("food-consumption.csv")

# %%
data.head()
# Out:
#    Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0  Germany           90              49   88       19.0      57.0
# 1    Italy           82              10   60        2.0      55.0
# 2   France           88              42   63        4.0      76.0
# 3  Holland           96              62   98       32.0      62.0
# 4  Belgium           94              38   48       11.0      74.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0           51        19        21           27  ...      81       75
# 1           41         3         2            4  ...      67       71
# 2           53        11        23           11  ...      87       84
# 3           67        43         7           14  ...      83       89
# 4           37        23         9           13  ...      76       76
#
#    Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# 0            44   71      22      91         85         74     30.0
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Real coffee', 'Instant coffee', 'Tea', 'Sweetener',
#        'Biscuits', 'Powder soup', 'Tin soup', 'Potatoes', 'Frozen fish',
#        'Frozen veggies', 'Apples', 'Oranges', 'Tinned fruit', 'Jam', 'Garlic',
#        'Butter', 'Margarine', 'Olive oil', 'Yoghurt', 'Crisp bread'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         16 non-null     object
#  1   Real coffee     16 non-null     int64
#  2   Instant coffee  16 non-null     int64
#  3   Tea             16 non-null     int64
#  4   Sweetener       15 non-null     float64
#  5   Biscuits        15 non-null     float64
#  6   Powder soup     16 non-null     int64
#  7   Tin soup        16 non-null     int64
#  8   Potatoes        16 non-null     int64
#  9   Frozen fish     16 non-null     int64
#  10  Frozen veggies  16 non-null     int64
#  11  Apples          16 non-null     int64
#  12  Oranges         16 non-null     int64
#  13  Tinned fruit    16 non-null     int64
#  14  Jam             16 non-null     int64
#  15  Garlic          16 non-null     int64
#  16  Butter          16 non-null     int64
# ...

# %%
data.shape
# Out:
# (16, 21)

# %%
data.describe()
# Out:
#        Real coffee  Instant coffee        Tea  Sweetener   Biscuits  \
# count    16.000000       16.000000  16.000000  15.000000  15.000000
# mean     78.562500       39.250000  78.500000  18.000000  60.666667
# std      23.145824       23.147354  18.540047  10.902162  19.841035
# min      27.000000       10.000000  40.000000   2.000000  22.000000
# 25%      71.500000       17.000000  62.500000  11.000000  56.000000
# 50%      89.000000       39.000000  84.500000  19.000000  62.000000
# 75%      96.000000       54.250000  92.250000  26.500000  75.000000
# max      98.000000       86.000000  99.000000  35.000000  91.000000
#
#        Powder soup   Tin soup   Potatoes  Frozen fish  Frozen veggies  \
# count    16.000000  16.000000  16.000000    16.000000        16.00000
# mean     49.000000  18.312500  12.750000    21.875000        15.87500
# std      15.427249  20.178268   9.574271    13.980343        12.78997
# min      27.000000   1.000000   2.000000     4.000000         2.00000
# ...

# %%
data.isnull().sum()
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         1
# Biscuits          1
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           1
# Crisp bread       0
# dtype: int64

# %%
data['Yoghurt']=data[['Yoghurt']].fillna(20)
data
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 10       Sweden           97              13   93       31.0       NaN
# 11      Denmark           96              17   92       35.0      66.0
# ...

# %%
data['Biscuits']=data['Biscuits'].fillna(60.66)
data
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0     57.00
# 1         Italy           82              10   60        2.0     55.00
# 2        France           88              42   63        4.0     76.00
# 3       Holland           96              62   98       32.0     62.00
# 4       Belgium           94              38   48       11.0     74.00
# 5    Luxembourg           97              61   86       28.0     79.00
# 6       England           27              86   99       22.0     91.00
# 7      Portugal           72              26   77        2.0     22.00
# 8       Austria           55              31   61       15.0     29.00
# 9   Switzerland           73              72   85       25.0     31.00
# 10       Sweden           97              13   93       31.0     60.66
# 11      Denmark           96              17   92       35.0     66.00
# ...

# %%
data.isnull().sum()
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         1
# Biscuits          0
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           0
# Crisp bread       0
# dtype: int64

# %%
data[['Real coffee','Instant coffee']].hist(figsize=(11,7))
# Out:
# array([[<AxesSubplot:title={'center':'Real coffee'}>,
#         <AxesSubplot:title={'center':'Instant coffee'}>]], dtype=object)

# %%
data['Sweetener']=data['Sweetener'].fillna(18)

# %%
data
data.isnull().any()
data['Country']
# Out:
# 0         Germany
# 1           Italy
# 2          France
# 3         Holland
# 4         Belgium
# 5      Luxembourg
# 6         England
# 7        Portugal
# 8         Austria
# 9     Switzerland
# 10         Sweden
# 11        Denmark
# 12         Norway
# 13        Finland
# 14          Spain
# 15        Ireland
# Name: Country, dtype: object

# %%
data[['Country','Biscuits','Sweetener']].plot.bar(0,subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'Biscuits'}, xlabel='Country'>,
#        <AxesSubplot:title={'center':'Sweetener'}, xlabel='Country'>],
#       dtype=object)

# %%
data.describe()
# Out:
#        Real coffee  Instant coffee        Tea  Sweetener   Biscuits  \
# count    16.000000       16.000000  16.000000  16.000000  16.000000
# mean     78.562500       39.250000  78.500000  18.000000  60.666250
# std      23.145824       23.147354  18.540047  10.532489  19.168261
# min      27.000000       10.000000  40.000000   2.000000  22.000000
# 25%      71.500000       17.000000  62.500000  11.000000  56.500000
# 50%      89.000000       39.000000  84.500000  18.500000  62.000000
# 75%      96.000000       54.250000  92.250000  25.750000  74.500000
# max      98.000000       86.000000  99.000000  35.000000  91.000000
#
#        Powder soup   Tin soup   Potatoes  Frozen fish  Frozen veggies  \
# count    16.000000  16.000000  16.000000    16.000000        16.00000
# mean     49.000000  18.312500  12.750000    21.875000        15.87500
# std      15.427249  20.178268   9.574271    13.980343        12.78997
# min      27.000000   1.000000   2.000000     4.000000         2.00000
# ...

# %% [markdown]
# ## Movie-Statistics-Dataset

# %%
Movie=pd.read_csv("movie_statistic_dataset.csv")

# %%
Movie.head()
# Out:
#                                    movie_title production_date  \
# 0                     Avatar: The Way of Water      2022-12-09
# 1                            Avengers: Endgame      2019-04-23
# 2  Pirates of the Caribbean: On Stranger Tides      2011-05-20
# 3                      Avengers: Age of Ultron      2015-04-22
# 4                       Avengers: Infinity War      2018-04-25
#
#                      genres  runtime_minutes  director_name  \
# 0  Action,Adventure,Fantasy            192.0  James Cameron
# 1    Action,Adventure,Drama            181.0              -
# 2  Action,Adventure,Fantasy            137.0   Rob Marshall
# 3   Action,Adventure,Sci-Fi            141.0    Joss Whedon
# 4   Action,Adventure,Sci-Fi            149.0              -
#
#               director_professions director_birthYear director_deathYear  \
# 0         writer,producer,director               1954              alive
# 1                                -                  -                  -
# ...

# %%
Movie.columns
# Out:
# Index(['movie_title', 'production_date', 'genres', 'runtime_minutes',
#        'director_name', 'director_professions', 'director_birthYear',
#        'director_deathYear', 'movie_averageRating', 'movie_numerOfVotes',
#        'approval_Index', 'Production budget $', 'Domestic gross $',
#        'Worldwide gross $'],
#       dtype='object')

# %%
Movie.isnull().sum()
# Out:
# movie_title             0
# production_date         0
# genres                  0
# runtime_minutes         0
# director_name           0
# director_professions    0
# director_birthYear      0
# director_deathYear      0
# movie_averageRating     0
# movie_numerOfVotes      0
# approval_Index          0
# Production budget $     0
# Domestic gross $        0
# Worldwide gross $       0
# dtype: int64

# %%
Movie.isnull().any()
# Out:
# movie_title             False
# production_date         False
# genres                  False
# runtime_minutes         False
# director_name           False
# director_professions    False
# director_birthYear      False
# director_deathYear      False
# movie_averageRating     False
# movie_numerOfVotes      False
# approval_Index          False
# Production budget $     False
# Domestic gross $        False
# Worldwide gross $       False
# dtype: bool

# %%
Movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4380 entries, 0 to 4379
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_title           4380 non-null   object
#  1   production_date       4380 non-null   object
#  2   genres                4380 non-null   object
#  3   runtime_minutes       4380 non-null   float64
#  4   director_name         4380 non-null   object
#  5   director_professions  4380 non-null   object
#  6   director_birthYear    4380 non-null   object
#  7   director_deathYear    4380 non-null   object
#  8   movie_averageRating   4380 non-null   float64
#  9   movie_numerOfVotes    4380 non-null   float64
#  10  approval_Index        4380 non-null   float64
#  11  Production budget $   4380 non-null   int64
#  12  Domestic gross $      4380 non-null   int64
#  13  Worldwide gross $     4380 non-null   int64
# dtypes: float64(4), int64(3), object(7)
# ...

# %%
Movie.describe()
# Out:
#        runtime_minutes  movie_averageRating  movie_numerOfVotes  \
# count      4380.000000          4380.000000        4.380000e+03
# mean        109.786073             6.407443        1.369603e+05
# std          20.375581             1.024000        2.150757e+05
# min          63.000000             1.500000        5.000000e+00
# 25%          96.000000             5.800000        2.140650e+04
# 50%         106.000000             6.500000        6.497950e+04
# 75%         120.000000             7.100000        1.598605e+05
# max         271.000000             9.300000        2.695887e+06
#
#        approval_Index  Production budget $  Domestic gross $  \
# count     4380.000000         4.380000e+03      4.380000e+03
# mean         5.032633         3.869377e+07      5.256385e+07
# std          1.384890         4.573772e+07      7.508813e+07
# min          0.395487         5.000000e+04      2.640000e+02
# 25%          4.178267         1.000000e+07      8.866234e+06
# ...

# %%
Movie[['movie_title','director_name']].head(10)
# Out:
#                                    movie_title   director_name
# 0                     Avatar: The Way of Water   James Cameron
# 1                            Avengers: Endgame               -
# 2  Pirates of the Caribbean: On Stranger Tides    Rob Marshall
# 3                      Avengers: Age of Ultron     Joss Whedon
# 4                       Avengers: Infinity War               -
# 5                               Justice League     Zack Snyder
# 6                                      Spectre      Sam Mendes
# 7                      Solo: A Star Wars Story      Ron Howard
# 8                                  John Carter  Andrew Stanton
# 9           Batman v Superman: Dawn of Justice     Zack Snyder

# %%
Movie_sortby_Worldwide_gross=Movie.sort_values(by=['Worldwide gross $']).tail(20)

# %%
Movie
# Out:
#                                       movie_title production_date  \
# 0                        Avatar: The Way of Water      2022-12-09
# 1                               Avengers: Endgame      2019-04-23
# 2     Pirates of the Caribbean: On Stranger Tides      2011-05-20
# 3                         Avengers: Age of Ultron      2015-04-22
# 4                          Avengers: Infinity War      2018-04-25
# ...                                           ...             ...
# 4375                                Super Size Me      2004-05-07
# 4376                        The Brothers McMullen      1995-08-09
# 4377                                     Gabriela      2001-03-16
# 4378                               Tiny Furniture      2010-11-12
# 4379                                     Counting      2015-07-31
#
#                         genres  runtime_minutes       director_name  \
# 0     Action,Adventure,Fantasy            192.0       James Cameron
# ...

# %%
Top20_Movies=Movie_sortby_Worldwide_gross

# %%
Top20_Movies[['movie_title','Worldwide gross $']].plot.bar(0,color="black",figsize=(10,6))
plt.savefig("TopMovies")

# %%
Top20_Movies[['movie_title','Worldwide gross $','Production budget $']].plot.bar(0,color=['black','red'],subplots=True)
plt.show()
plt.savefig("WPC")

# %%
Top20_Movies[['movie_title','Worldwide gross $','Production budget $']].plot.bar(0,color=['black','red'])
plt.savefig('movie_title')

# %% [markdown]
# Avatar Movie is High Grossing  Movie with low Production Budget

# %%
Movie[['director_name' ]].value_counts()
# Out:
# director_name
# -                   326
# Steven Spielberg     25
# Clint Eastwood       24
# Ridley Scott         21
# Woody Allen          20
#                    ...
# Joe Chappelle         1
# Joe Camp              1
# Joe Berlinger         1
# Jody Hill             1
# Émile Gaudreault      1
# Length: 1835, dtype: int64

# %%
Director_Movie=Movie.groupby(['director_name']).sum()

# %%
Director_Movie=Director_Movie.sort_values(by=['Worldwide gross $'],axis=0).tail(20)

# %%
Director_Movie
# Out:
#                    runtime_minutes  movie_averageRating  movie_numerOfVotes  \
# director_name
# Chris Columbus              1226.0                 66.2           2501522.0
# Joss Whedon                  403.0                 23.1           2566979.0
# Clint Eastwood              3044.0                171.1           4809878.0
# Sam Mendes                   991.0                 60.2           3644178.0
# James Wan                    800.0                 48.0           2080255.0
# Bryan Singer                1009.0                 58.0           4089498.0
# Robert Zemeckis             1727.0                101.8           6491208.0
# Ron Howard                  2025.0                110.4           4009302.0
# Roland Emmerich             1496.0                 68.9           2703921.0
# Tim Burton                  1672.0                104.7           4403008.0
# Jon Favreau                  666.0                 42.4           2722584.0
# ...

# %%
Director_Movie[['Worldwide gross $','Production budget $']].plot.bar(width=0.8,color=["pink","orange"])
plt.savefig("Director-Name")

# %% [markdown]
# Steven Speilberg and James Cameron with highest worldwide gross adding all its movies

# %%
Movie.describe()
# Out:
#        runtime_minutes  movie_averageRating  movie_numerOfVotes  \
# count      4380.000000          4380.000000        4.380000e+03
# mean        109.786073             6.407443        1.369603e+05
# std          20.375581             1.024000        2.150757e+05
# min          63.000000             1.500000        5.000000e+00
# 25%          96.000000             5.800000        2.140650e+04
# 50%         106.000000             6.500000        6.497950e+04
# 75%         120.000000             7.100000        1.598605e+05
# max         271.000000             9.300000        2.695887e+06
#
#        approval_Index  Production budget $  Domestic gross $  \
# count     4380.000000         4.380000e+03      4.380000e+03
# mean         5.032633         3.869377e+07      5.256385e+07
# std          1.384890         4.573772e+07      7.508813e+07
# min          0.395487         5.000000e+04      2.640000e+02
# 25%          4.178267         1.000000e+07      8.866234e+06
# ...

# %%
Movie.tail()
x=Movie['movie_averageRating'].head(2000).values.reshape(-1,1)

# %%
x=x.astype("int64")
type(x)
Movie.columns
Movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4380 entries, 0 to 4379
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_title           4380 non-null   object
#  1   production_date       4380 non-null   object
#  2   genres                4380 non-null   object
#  3   runtime_minutes       4380 non-null   float64
#  4   director_name         4380 non-null   object
#  5   director_professions  4380 non-null   object
#  6   director_birthYear    4380 non-null   object
#  7   director_deathYear    4380 non-null   object
#  8   movie_averageRating   4380 non-null   float64
#  9   movie_numerOfVotes    4380 non-null   float64
#  10  approval_Index        4380 non-null   float64
#  11  Production budget $   4380 non-null   int64
#  12  Domestic gross $      4380 non-null   int64
#  13  Worldwide gross $     4380 non-null   int64
# dtypes: float64(4), int64(3), object(7)
# ...

# %%
y=Movie['Worldwide gross $'].head(2000).values.reshape(-1,1)

# %%
y
type(y)
print(y.dtype)
print(x.dtype)
# Out:
# int64
# int64

# %%
plt.scatter(x,y)
plt.show()

# %%
Fdata=Movie[Movie['movie_averageRating'] > 8]
Fdata
# Out:
#                           movie_title production_date  \
# 1                   Avengers: Endgame      2019-04-23
# 4              Avengers: Infinity War      2018-04-25
# 22              The Dark Knight Rises      2012-07-19
# 41            Spider-Man: No Way Home      2021-12-14
# 48                        Toy Story 3      2010-06-18
# ...                               ...             ...
# 4283             The Other Dream Team      2012-09-21
# 4286                             Home      2009-04-23
# 4296  Monty Python and the Holy Grail      1975-05-10
# 4307            It Happened One Night      1934-02-22
# 4347                         Solitude      2005-01-07
#
#                           genres  runtime_minutes          director_name  \
# 1         Action,Adventure,Drama            181.0                      -
# 4        Action,Adventure,Sci-Fi            149.0                      -
# 22                  Action,Drama            164.0      Christopher Nolan
# ...

# %%
Fdata[['movie_title','director_name','movie_averageRating','Production budget $','Worldwide gross $']].head(20).plot.bar(0)
T20=Top20_Movies[['movie_title','Worldwide gross $','Production budget $']].plot.bar(0,color=['black','red'])#subplots=True)
plt.show()

# %%
Movie.columns
# Out:
# Index(['movie_title', 'production_date', 'genres', 'runtime_minutes',
#        'director_name', 'director_professions', 'director_birthYear',
#        'director_deathYear', 'movie_averageRating', 'movie_numerOfVotes',
#        'approval_Index', 'Production budget $', 'Domestic gross $',
#        'Worldwide gross $'],
#       dtype='object')

# %%
import seaborn as sns
usb=pd.read_csv("UJJIVANSFB.csv")

# %%
usb
# Out:
#            Date      Symbol Series  Prev Close   Open   High    Low   Last  \
# 0    2019-12-12  UJJIVANSFB     EQ       37.00  58.75  62.80  53.05  55.30
# 1    2019-12-13  UJJIVANSFB     EQ       55.95  55.40  55.40  51.10  52.55
# 2    2019-12-16  UJJIVANSFB     EQ       52.00  52.00  59.65  51.25  59.05
# 3    2019-12-17  UJJIVANSFB     EQ       58.45  60.35  61.10  57.50  58.90
# 4    2019-12-18  UJJIVANSFB     EQ       58.65  58.55  58.90  56.75  57.60
# ..          ...         ...    ...         ...    ...    ...    ...    ...
# 383  2021-06-25  UJJIVANSFB     EQ       30.80  30.95  31.35  30.25  30.80
# 384  2021-06-28  UJJIVANSFB     EQ       30.75  30.85  32.40  30.70  32.00
# 385  2021-06-29  UJJIVANSFB     EQ       31.70  31.95  31.95  31.05  31.15
# 386  2021-06-30  UJJIVANSFB     EQ       31.15  31.20  31.35  30.70  30.75
# 387  2021-07-01  UJJIVANSFB     EQ       30.75  30.75  31.10  30.55  30.65
#
# ...

# %%
usb.isnull().sum()
# Out:
# Date                  0
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
usb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                388 non-null    object
#  1   Symbol              388 non-null    object
#  2   Series              388 non-null    object
#  3   Prev Close          388 non-null    float64
#  4   Open                388 non-null    float64
#  5   High                388 non-null    float64
#  6   Low                 388 non-null    float64
#  7   Last                388 non-null    float64
#  8   Close               388 non-null    float64
#  9   VWAP                388 non-null    float64
#  10  Volume              388 non-null    int64
#  11  Turnover            388 non-null    float64
#  12  Trades              388 non-null    int64
#  13  Deliverable Volume  388 non-null    int64
#  14  %Deliverble         388 non-null    float64
# ...

# %%
usb[['Date','Open','High']].plot.line(0,figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
usb[['Date','Open','High']].plot.line(0,figsize=(12,5), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
x=usb.iloc[:,4].values.reshape(-1,1)
x
# Out:
# array([[58.75],
#        [55.4 ],
#        [52.  ],
#        [60.35],
#        [58.55],
#        [57.1 ],
#        [58.8 ],
#        [57.75],
#        [56.5 ],
#        [55.55],
#        [53.9 ],
#        [53.4 ],
#        [54.  ],
#        [53.85],
#        [53.3 ],
#        [55.6 ],
#        [54.8 ],
#        [53.5 ],
#        [52.7 ],
#        [55.  ],
#        [53.3 ],
#        [52.25],
#        [52.85],
#        [52.9 ],
#        [51.95],
#        [51.7 ],
#        [50.75],
#        [49.25],
#        [50.8 ],
#        [52.  ],
#        [54.  ],
#        [55.  ],
#        [54.6 ],
#        [55.5 ],
#        [54.9 ],
#        [56.1 ],
#        [56.  ],
#        [53.5 ],
#        [53.9 ],
#        [53.7 ],
#        [56.2 ],
#        [56.85],
#        [55.8 ],
#        [55.1 ],
#        [55.  ],
#        [54.05],
#        [55.  ],
#        [54.  ],
#        [53.05],
#        [53.  ],
#        [52.8 ],
#        [53.  ],
#        [51.65],
#        [51.  ],
#        [50.  ],
# ...

# %%
y=usb.iloc[:,6].values.reshape(-1,1)
y
# Out:
# array([[53.05],
#        [51.1 ],
#        [51.25],
#        [57.5 ],
#        [56.75],
#        [56.65],
#        [57.6 ],
#        [56.2 ],
#        [55.3 ],
#        [53.2 ],
#        [53.15],
#        [53.3 ],
#        [53.75],
#        [52.9 ],
#        [52.9 ],
#        [54.65],
#        [53.  ],
#        [53.25],
#        [52.1 ],
#        [52.9 ],
#        [51.8 ],
#        [52.25],
#        [52.3 ],
#        [51.6 ],
#        [51.2 ],
#        [50.3 ],
#        [48.6 ],
#        [48.35],
#        [49.75],
#        [52.  ],
#        [53.7 ],
#        [54.  ],
#        [54.5 ],
#        [54.8 ],
#        [53.85],
#        [55.55],
#        [52.55],
#        [53.  ],
#        [53.4 ],
#        [53.6 ],
#        [55.8 ],
#        [55.75],
#        [54.5 ],
#        [54.1 ],
#        [54.1 ],
#        [53.6 ],
#        [54.1 ],
#        [53.2 ],
#        [52.2 ],
#        [52.9 ],
#        [52.45],
#        [51.5 ],
#        [50.85],
#        [49.15],
#        [48.65],
# ...

# %%
y.shape
# Out:
# (388, 1)

# %%
plt.scatter(x,y,color="pink")

# %%
plt.boxplot(x)
plt.show()

# %%
mul=x*y

# %%
mul
# Out:
# array([[3116.6875],
#        [2830.94  ],
#        [2665.    ],
#        [3470.125 ],
#        [3322.7125],
#        [3234.715 ],
#        [3386.88  ],
#        [3245.55  ],
#        [3124.45  ],
#        [2955.26  ],
#        [2864.785 ],
#        [2846.22  ],
#        [2902.5   ],
#        [2848.665 ],
#        [2819.57  ],
#        [3038.54  ],
#        [2904.4   ],
#        [2848.875 ],
#        [2745.67  ],
#        [2909.5   ],
#        [2760.94  ],
#        [2730.0625],
#        [2764.055 ],
#        [2729.64  ],
#        [2659.84  ],
#        [2600.51  ],
#        [2466.45  ],
#        [2381.2375],
#        [2527.3   ],
#        [2704.    ],
#        [2899.8   ],
#        [2970.    ],
#        [2975.7   ],
#        [3041.4   ],
#        [2956.365 ],
#        [3116.355 ],
#        [2942.8   ],
#        [2835.5   ],
#        [2878.26  ],
#        [2878.32  ],
#        [3135.96  ],
#        [3169.3875],
#        [3041.1   ],
#        [2980.91  ],
#        [2975.5   ],
# ...

# %%
vol=usb.iloc[:,10].values.reshape(-1,1)

# %%
plt.plot(mul,color="r")
plt.show()

# %% [markdown]
# ## NIFTY IT INDEX

# %%
NIFTY_IT=pd.read_csv("NIFTY IT.csv")

# %%
NIFTY_IT
# Out:
#             Date      Open      High       Low     Close      Volume  \
# 0     1996-01-01      0.00      0.00      0.00   1000.00         NaN
# 1     1996-01-02      0.00      0.00      0.00    995.84     66050.0
# 2     1996-01-03      0.00      0.00      0.00    986.97     50000.0
# 3     1996-01-04      0.00      0.00      0.00    980.39     81600.0
# 4     1996-01-05      0.00      0.00      0.00    984.08     83400.0
# ...          ...       ...       ...       ...       ...         ...
# 6322  2021-06-25  29176.75  29284.00  28874.60  29210.55  27880485.0
# 6323  2021-06-28  29259.60  29259.60  28977.75  29068.55  14668333.0
# 6324  2021-06-29  29049.65  29183.85  28934.15  28986.25  21706364.0
# 6325  2021-06-30  29057.15  29311.55  29036.95  29168.00  18722780.0
# 6326  2021-07-01  29193.05  29193.05  28953.05  29003.10  15933961.0
#
#           Turnover
# 0              NaN
# 1     6.800000e+06
# 2     2.900000e+06
# 3     7.800000e+06
# 4     5.100000e+06
# ...

# %%
NIFTY_IT.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume      11
# Turnover    11
# dtype: int64

# %%
NIT=NIFTY_IT

# %%
NIT.describe()
# Out:
#               Open          High           Low         Close        Volume  \
# count   6327.00000   6327.000000   6327.000000   6327.000000  6.316000e+03
# mean    6510.45426   6569.383246   6449.919701  11053.228649  2.058477e+07
# std     6438.67109   6496.927146   6375.465712   9878.866457  1.799807e+07
# min        0.00000      0.000000      0.000000    762.470000  0.000000e+00
# 25%        0.00000      0.000000      0.000000   4593.150000  9.775997e+06
# 50%     5256.35000   5311.600000   5194.550000   9329.000000  1.534848e+07
# 75%    10788.02500  10845.700000  10711.150000  15120.925000  2.714003e+07
# max    29259.60000  29311.550000  29036.950000  95501.550000  3.546272e+08
#
#            Turnover
# count  6.316000e+03
# mean   1.227881e+10
# std    1.138690e+10
# min    0.000000e+00
# 25%    6.087300e+09
# 50%    9.481900e+09
# 75%    1.511498e+10
# max    1.687149e+11

# %%
NIT['Turnover']=NIT['Turnover'].fillna(1.227881e+10)
NIT['Volume']=NIT['Volume'].fillna(2.058477e+07)

# %%
NIT
# Out:
#             Date      Open      High       Low     Close      Volume  \
# 0     1996-01-01      0.00      0.00      0.00   1000.00  20584770.0
# 1     1996-01-02      0.00      0.00      0.00    995.84     66050.0
# 2     1996-01-03      0.00      0.00      0.00    986.97     50000.0
# 3     1996-01-04      0.00      0.00      0.00    980.39     81600.0
# 4     1996-01-05      0.00      0.00      0.00    984.08     83400.0
# ...          ...       ...       ...       ...       ...         ...
# 6322  2021-06-25  29176.75  29284.00  28874.60  29210.55  27880485.0
# 6323  2021-06-28  29259.60  29259.60  28977.75  29068.55  14668333.0
# 6324  2021-06-29  29049.65  29183.85  28934.15  28986.25  21706364.0
# 6325  2021-06-30  29057.15  29311.55  29036.95  29168.00  18722780.0
# 6326  2021-07-01  29193.05  29193.05  28953.05  29003.10  15933961.0
#
#           Turnover
# 0     1.227881e+10
# 1     6.800000e+06
# 2     2.900000e+06
# 3     7.800000e+06
# 4     5.100000e+06
# ...

# %%
NIT.isnull().sum()
# Out:
# Date        0
# Open        0
# High        0
# Low         0
# Close       0
# Volume      0
# Turnover    0
# dtype: int64

# %%
NIT.head(5)
# Out:
#          Date  Open  High  Low    Close      Volume      Turnover
# 0  1996-01-01   0.0   0.0  0.0  1000.00  20584770.0  1.227881e+10
# 1  1996-01-02   0.0   0.0  0.0   995.84     66050.0  6.800000e+06
# 2  1996-01-03   0.0   0.0  0.0   986.97     50000.0  2.900000e+06
# 3  1996-01-04   0.0   0.0  0.0   980.39     81600.0  7.800000e+06
# 4  1996-01-05   0.0   0.0  0.0   984.08     83400.0  5.100000e+06

# %%
NIT[['Date','Close']].plot.line(0,figsize=(12,6),color=["r","black"])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
NIT[['Date','Volume','Turnover']].plot.line(0,figsize=(12,6),color=['black','orange'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
NBANK=pd.read_csv("NIFTY BANK.csv")

# %%
NBANK
# Out:
#             Date      Open      High       Low     Close       Volume  \
# 0     2000-01-01       NaN       NaN       NaN   1000.00          NaN
# 1     2000-01-03       NaN       NaN       NaN   1054.81          NaN
# 2     2000-01-04       NaN       NaN       NaN   1092.08          NaN
# 3     2000-01-05       NaN       NaN       NaN   1055.99          NaN
# 4     2000-01-06       NaN       NaN       NaN   1086.67          NaN
# ...          ...       ...       ...       ...       ...          ...
# 5345  2021-06-25  34916.65  35491.95  34915.85  35364.65  236854047.0
# 5346  2021-06-28  35488.20  35576.95  35236.45  35359.45  320196203.0
# 5347  2021-06-29  35320.45  35337.45  34913.70  35010.30  266274918.0
# 5348  2021-06-30  35001.90  35214.90  34730.45  34772.20  249544293.0
# 5349  2021-07-01  34866.00  34917.65  34650.95  34684.00  164003666.0
#
#           Turnover
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...

# %%
NBANK.shape
# Out:
# (5350, 7)

# %%
NBANK.isnull().sum()
# Out:
# Date           0
# Open        1368
# High        1368
# Low         1368
# Close          0
# Volume       933
# Turnover     933
# dtype: int64

# %%
NBANK.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   3982.000000   3982.000000   3982.000000   5350.000000  4.417000e+03
# mean   14941.549146  15071.331755  14789.395643  11534.515273  8.643001e+07
# std     8598.790874   8645.123879   8533.950664   9417.380061  1.344123e+08
# min     3385.400000   3446.750000   3314.550000    743.700000  3.763050e+05
# 25%     8407.287500   8498.175000   8278.075000   3513.597500  1.554670e+07
# 50%    11784.550000  11892.750000  11644.625000   9561.100000  2.809134e+07
# 75%    21226.262500  21434.687500  20976.412500  18320.750000  8.651321e+07
# max    37492.600000  37708.750000  36764.250000  37306.250000  1.568143e+09
#
#            Turnover
# count  4.417000e+03
# mean   2.593481e+10
# std    2.811701e+10
# min    2.578000e+08
# 25%    8.983400e+09
# 50%    1.693780e+10
# 75%    2.842960e+10
# max    2.484574e+11

# %%
NBANK[['Date','Close']].plot.line(0,figsize=(12,6),color=["orange"])
NIT[['Date','Close']].plot.line(0,figsize=(12,6),color=["black"])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Movie.head()
# Out:
#                                    movie_title production_date  \
# 0                     Avatar: The Way of Water      2022-12-09
# 1                            Avengers: Endgame      2019-04-23
# 2  Pirates of the Caribbean: On Stranger Tides      2011-05-20
# 3                      Avengers: Age of Ultron      2015-04-22
# 4                       Avengers: Infinity War      2018-04-25
#
#                      genres  runtime_minutes  director_name  \
# 0  Action,Adventure,Fantasy            192.0  James Cameron
# 1    Action,Adventure,Drama            181.0              -
# 2  Action,Adventure,Fantasy            137.0   Rob Marshall
# 3   Action,Adventure,Sci-Fi            141.0    Joss Whedon
# 4   Action,Adventure,Sci-Fi            149.0              -
#
#               director_professions director_birthYear director_deathYear  \
# 0         writer,producer,director               1954              alive
# 1                                -                  -                  -
# ...

# %%
import statistics as scs
Rating=Movie.movie_averageRating.values
type(Rating)
Rating.shape
# Out:
# (4380,)

# %%
mode=scs.mode(Rating)

# %%
print(mode)
print(Movie[['movie_averageRating']].value_counts().head())
# Out:
# 6.6
# movie_averageRating
# 6.6                    208
# 6.4                    203
# 6.2                    199
# 6.5                    182
# 6.7                    173
# dtype: int64

# %%
mean=scs.mean(Rating)
print(mean)
Movie.describe()
# Out:
# 6.407442922374429
#        runtime_minutes  movie_averageRating  movie_numerOfVotes  \
# count      4380.000000          4380.000000        4.380000e+03
# mean        109.786073             6.407443        1.369603e+05
# std          20.375581             1.024000        2.150757e+05
# min          63.000000             1.500000        5.000000e+00
# 25%          96.000000             5.800000        2.140650e+04
# 50%         106.000000             6.500000        6.497950e+04
# 75%         120.000000             7.100000        1.598605e+05
# max         271.000000             9.300000        2.695887e+06
#
#        approval_Index  Production budget $  Domestic gross $  \
# count     4380.000000         4.380000e+03      4.380000e+03
# mean         5.032633         3.869377e+07      5.256385e+07
# std          1.384890         4.573772e+07      7.508813e+07
# min          0.395487         5.000000e+04      2.640000e+02
# 25%          4.178267         1.000000e+07      8.866234e+06
# ...

# %%
Runtime=Movie.runtime_minutes.values

# %%
Runtime
# Out:
# array([192., 181., 137., ...,  93.,  98., 111.])

# %%
mode=scs.mode(Runtime)
print(mode)
Movie[['runtime_minutes']].value_counts()
# Out:
# 100.0
# runtime_minutes
# 101.0              115
# 100.0              115
# 98.0               113
# 97.0               110
# 104.0              109
#                   ...
# 176.0                1
# 168.0                1
# 166.0                1
# 65.0                 1
# 271.0                1
# Length: 138, dtype: int64

# %%
Rmin=Movie[Movie['runtime_minutes'] ==100]

# %%
Rmin=Rmin.sort_values(by=['Worldwide gross $']).tail(20)

# %%
Rmin[['movie_title','runtime_minutes','Worldwide gross $']].plot.bar(0,subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'runtime_minutes'}, xlabel='movie_title'>,
#        <AxesSubplot:title={'center':'Worldwide gross $'}, xlabel='movie_title'>],
#       dtype=object)

# %%
AvgRating=Movie[ Movie['movie_averageRating'] > 7.7].sort_values(by=['Worldwide gross $']).tail(20)

# %%
Movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4380 entries, 0 to 4379
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_title           4380 non-null   object
#  1   production_date       4380 non-null   object
#  2   genres                4380 non-null   object
#  3   runtime_minutes       4380 non-null   float64
#  4   director_name         4380 non-null   object
#  5   director_professions  4380 non-null   object
#  6   director_birthYear    4380 non-null   object
#  7   director_deathYear    4380 non-null   object
#  8   movie_averageRating   4380 non-null   float64
#  9   movie_numerOfVotes    4380 non-null   float64
#  10  approval_Index        4380 non-null   float64
#  11  Production budget $   4380 non-null   int64
#  12  Domestic gross $      4380 non-null   int64
#  13  Worldwide gross $     4380 non-null   int64
# dtypes: float64(4), int64(3), object(7)
# ...

# %%
AvgRating[['movie_title','Worldwide gross $']].plot.bar(0,color=['indigo','green'])
Top20_Movies[['movie_title','Worldwide gross $']].plot.bar(0,color=['green','red'])
AvgRating
Top20_Movies
# Out:
#                         movie_title production_date  \
# 50                       Iron Man 3      2013-04-24
# 18          The Fate of the Furious      2017-04-07
# 44                    Incredibles 2      2018-06-15
# 171                          Frozen      2013-11-22
# 151            Beauty and the Beast      2017-03-16
# 128  Jurassic World: Fallen Kingdom      2018-06-06
# 42                    Black Panther      2018-02-13
# 3           Avengers: Age of Ultron      2015-04-22
# 169                       Frozen II      2019-11-20
# 127               Top Gun: Maverick      2022-05-20
# 80                        Furious 7      2015-04-01
# 25                     The Avengers      2012-04-25
# 10                    The Lion King      2019-07-11
# 32                   Jurassic World      2015-06-09
# 41          Spider-Man: No Way Home      2021-12-14
# 4            Avengers: Infinity War      2018-04-25
# 43                          Titanic      1997-12-18
# ...

# %%
Top20_Movies[['movie_title','Worldwide gross $']].plot.bar(0,color=['black','red'],figsize=(11,6))
# Out:
# <AxesSubplot:xlabel='movie_title'>

# %%
Movie.describe()
# Out:
#        runtime_minutes  movie_averageRating  movie_numerOfVotes  \
# count      4380.000000          4380.000000        4.380000e+03
# mean        109.786073             6.407443        1.369603e+05
# std          20.375581             1.024000        2.150757e+05
# min          63.000000             1.500000        5.000000e+00
# 25%          96.000000             5.800000        2.140650e+04
# 50%         106.000000             6.500000        6.497950e+04
# 75%         120.000000             7.100000        1.598605e+05
# max         271.000000             9.300000        2.695887e+06
#
#        approval_Index  Production budget $  Domestic gross $  \
# count     4380.000000         4.380000e+03      4.380000e+03
# mean         5.032633         3.869377e+07      5.256385e+07
# std          1.384890         4.573772e+07      7.508813e+07
# min          0.395487         5.000000e+04      2.640000e+02
# 25%          4.178267         1.000000e+07      8.866234e+06
# ...

# %%
data.describe()
# Out:
#        Real coffee  Instant coffee        Tea  Sweetener   Biscuits  \
# count    16.000000       16.000000  16.000000  16.000000  16.000000
# mean     78.562500       39.250000  78.500000  18.000000  60.666250
# std      23.145824       23.147354  18.540047  10.532489  19.168261
# min      27.000000       10.000000  40.000000   2.000000  22.000000
# 25%      71.500000       17.000000  62.500000  11.000000  56.500000
# 50%      89.000000       39.000000  84.500000  18.500000  62.000000
# 75%      96.000000       54.250000  92.250000  25.750000  74.500000
# max      98.000000       86.000000  99.000000  35.000000  91.000000
#
#        Powder soup   Tin soup   Potatoes  Frozen fish  Frozen veggies  \
# count    16.000000  16.000000  16.000000    16.000000        16.00000
# mean     49.000000  18.312500  12.750000    21.875000        15.87500
# std      15.427249  20.178268   9.574271    13.980343        12.78997
# min      27.000000   1.000000   2.000000     4.000000         2.00000
# ...

# %%
data[['Real coffee','Instant coffee']].boxplot()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.boxplot(x='movie_averageRating',y='Worldwide gross $',data=Movie.head(15))
# Out:
# <AxesSubplot:xlabel='movie_averageRating', ylabel='Worldwide gross $'>

# %%
sns.lineplot(x = 'movie_averageRating',y='Worldwide gross $',data = Movie.head(50))
plt.show()

# %%
sns.displot(Movie['movie_averageRating'])

# %%
sns.displot(Movie['Worldwide gross $'])

# %%
Movie['movie_averageRating'].plot.hist(color="indigo")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Movie['movie_averageRating'].value_counts()
# Out:
# 6.6    208
# 6.4    203
# 6.2    199
# 6.5    182
# 6.7    173
#       ...
# 2.0      1
# 1.6      1
# 8.9      1
# 9.2      1
# 2.6      1
# Name: movie_averageRating, Length: 74, dtype: int64

# %%
from IPython.display import Image

# %%
url='https://housing.com/news/wp-content/uploads/2022/11/image1-30.jpg'
Image(url,width=200,height=100)
